# %% [markdown]
# # Custom Chatbot Project

# %% [markdown]
# I selected the character_descriptions.csv dataset and GPT-3.5-turbo-instruct to demonstrate how a domain-specific dataset can enhance AI-generated responses in a targeted context. This combination showcases how structured data about characters enables the model to provide relevant, context-aware interactions, illustrating the effectiveness of domain-driven AI applications.

# %% [markdown]
# ## Data Wrangling
#
# TODO: In the cells below, load your chosen dataset into a `pandas` dataframe with a column named `"text"`. This column should contain all of your text data, separated into at least 20 rows.

# %%
import pandas as pd

df = pd.read_csv('data/character_descriptions.csv')

# Add concatenated text to the dataframe
df['text'] = df['Name'] + " is a character in a " + df['Medium'] + ". " + df['Description'] + " The story is set in " + df['Setting'] + "."

df.iloc[0]["text"]
# Out:
# "Emily is a character in a Play. A young woman in her early 20s, Emily is an aspiring actress and Alice's daughter. She has a bubbly personality and a quick wit, but struggles with self-doubt and insecurity. She's also in a relationship with George. The story is set in England."

# %%
import openai

openai.api_key = "YOUR API KEY"

EMBEDDING_MODEL_NAME = "text-embedding-ada-002"
batch_size = 100
embeddings = []
for i in range(0, len(df), batch_size):
    response = openai.Embedding.create(
        input=df.iloc[i:i+batch_size]["text"].tolist(),
        engine=EMBEDDING_MODEL_NAME
    )
    embeddings.extend([data["embedding"] for data in response["data"]])

# Add embeddings list to dataframe
df["embeddings"] = embeddings

# %%
df
# Out:
#                     Name                                        Description  \
# 0                  Emily  A young woman in her early 20s, Emily is an as...
# 1                   Jack  A middle-aged man in his 40s, Jack is a succes...
# 2                  Alice  A woman in her late 30s, Alice is a warm and n...
# 3                    Tom  A man in his 50s, Tom is a retired soldier and...
# 4                  Sarah  A woman in her mid-20s, Sarah is a free-spirit...
# 5                 George  A man in his early 30s, George is a charming a...
# 6                 Rachel  A woman in her late 20s, Rachel is a shy and i...
# 7                   John  A man in his 60s, John is a retired professor ...
# 8                  Maria  A middle-aged Latina woman in her 40s, Maria i...
# 9                  Caleb  A young African American man in his early 20s,...
# 10                 Tyler  A white man in his mid-30s, Tyler is a tough-a...
# 11                 Sonya  A white woman in her late 20s, Sonya is a free...
# 12                Manuel  A middle-aged Hispanic man in his 50s, Manuel ...
# 13                  Will  A white man in his early 40s, Will is a succes...
# 14                   Mia  A young Australian woman in her mid-20s, Mia i...
# 15                 Lucas  A middle-aged Australian man in his 40s, Lucas...
# 16                Tahlia  A young Indigenous Australian woman in her ear...
# 17                   Max  A white Australian man in his late 20s, Max is...
# 18                   Ava  A middle-aged Australian woman in her 50s, Ava...
# 19                 Donna  A seasoned performer with a larger-than-life p...
# 20                Johnny  A young up-and-coming performer, Johnny is ful...
# 21                 Sable  A sultry and dramatic performer, Sable exudes ...
# 22                 Dolly  A bubbly and vivacious performer, Dolly is a f...
# 23                 Vixen  A fierce and competitive performer, Vixen is a...
# 24                 Karma  A chameleon-like performer, Karma is known for...
# 25               Crystal  A quirky and imaginative performer, Crystal is...
# 26                Olivia  A confident and charismatic marketing executiv...
# 54          Sitcom             USA
#
#                                                  text  \
# 0   Emily is a character in a Play. A young woman ...
# 1   Jack is a character in a Play. A middle-aged m...
# 2   Alice is a character in a Play. A woman in her...
# 3   Tom is a character in a Play. A man in his 50s...
# 4   Sarah is a character in a Play. A woman in her...
# 5   George is a character in a Play. A man in his ...
# 6   Rachel is a character in a Play. A woman in he...
# 7   John is a character in a Play. A man in his 60...
# 8   Maria is a character in a Movie. A middle-aged...
# 9   Caleb is a character in a Movie. A young Afric...
# 10  Tyler is a character in a Movie. A white man i...
# 11  Sonya is a character in a Movie. A white woman...
# 12  Manuel is a character in a Movie. A middle-age...
# 13  Will is a character in a Movie. A white man in...
# 14  Mia is a character in a Limited Series. A youn...
# 15  Lucas is a character in a Limited Series. A mi...
# 16  Tahlia is a character in a Limited Series. A y...
# 17  Max is a character in a Limited Series. A whit...
# 18  Ava is a character in a Limited Series. A midd...
# 19  Donna is a character in a Musical. A seasoned ...
# 20  Johnny is a character in a Musical. A young up...
# 21  Sable is a character in a Musical. A sultry an...
# 22  Dolly is a character in a Musical. A bubbly an...
# 23  Vixen is a character in a Musical. A fierce an...
# 24  Karma is a character in a Musical. A chameleon...
# 25  Crystal is a character in a Musical. A quirky ...
# 26  Olivia is a character in a Reality Show. A con...
# 27  Marcus is a character in a Reality Show. A cha...
# 28  Maya is a character in a Reality Show. A kind ...
# 29  James is a character in a Reality Show. A hand...
# 30  Sophia is a character in a Reality Show. A fun...
# 31  Noah is a character in a Reality Show. A quirk...
# 32  Chloe is a character in a Reality Show. A driv...
# 33  Jake is a character in a Reality Show. A laid-...
# 34  Prince Lorenzo is a character in a Opera. A ch...
# 35  Signora Rosa is a character in a Opera. A myst...
# 36  Baron Gustavo is a character in a Opera. A wea...
# 37  Francesca is a character in a Opera. A fiery a...
# 38  Don Carlo is a character in a Opera. A charmin...
# 39  Duke Orsino is a character in a Play. A pompou...
# 40  Lady Olivia is a character in a Play. A wealth...
# 41  Sir Toby Belch is a character in a Play. A dru...
# 42  Malvolio is a character in a Play. A pompous a...
# 43  Viola is a character in a Play. A plucky and r...
# 44  Sir Andrew Aguecheek is a character in a Play....
# 45  Bianca is a character in a Play. Lady Olivia's...
# 46  Sebastian is a character in a Play. Viola's tw...
# 47  Feste is a character in a Play. A jester and m...
# 48  Antonio is a character in a Play. A sea captai...
# 49  Abigail is a character in a Sitcom. A plucky a...
# 50  Thomas is a character in a Sitcom. A good-natu...
# 51  Reverend Brown is a character in a Sitcom. The...
# 52  Captain James is a character in a Sitcom. The ...
# 53  Mrs. Mercer is a character in a Sitcom. The ma...
# 54  Mr. Mercer is a character in a Sitcom. The bum...
#
#                                            embeddings
# 0   [-0.016368035227060318, -0.014631644822657108,...
# 1   [0.0023951339535415173, -0.027941077947616577,...
# 2   [0.007741514127701521, -0.011314022354781628, ...
# 3   [0.015514831058681011, -0.020425723865628242, ...
# 4   [-0.01451121736317873, -0.03126079961657524, -...
# 5   [-0.01863767020404339, -0.015743380412459373, ...
# 6   [-0.006452818401157856, -0.014104107394814491,...
# 7   [0.017432034015655518, -0.017279010266065598, ...
# 8   [-0.01244370173662901, -0.019594186916947365, ...
# 9   [0.006574748549610376, -0.030858173966407776, ...
# 10  [0.009816470555961132, -0.049798741936683655, ...
# 11  [0.0028479069005697966, -0.027940496802330017,...
# 12  [-0.014727214351296425, -0.023791132494807243,...
# 13  [-0.00728572066873312, -0.04460698738694191, -...
# 14  [-0.012351165525615215, -0.022184068337082863,...
# 15  [0.0026741118635982275, -0.0170036181807518, -...
# 16  [-0.011918366886675358, -0.014478801749646664,...
# 17  [-0.00026815407909452915, -0.03790075331926346...
# 18  [9.845461318036541e-05, -0.013735860586166382,...
# 19  [-0.02831415645778179, -0.01762465015053749, 0...
# 20  [-0.028036687523126602, -0.021027516573667526,...
# 21  [-0.029506079852581024, -0.01870235614478588, ...
# 22  [-0.035160064697265625, -0.01963837258517742, ...
# 23  [-0.03357435762882233, -0.026927525177598, 0.0...
# 24  [-0.00107478816062212, -0.02119309827685356, 0...
# 25  [-0.006420883350074291, -0.02087603509426117, ...
# 26  [-0.00042307059629820287, -0.01519947499036789...
# 27  [0.0003506191133055836, -0.03934405371546745, ...
# 28  [-0.02221345342695713, -0.0217245202511549, -0...
# 29  [-0.017906880006194115, -0.010714348405599594,...
# 30  [0.024226823821663857, -0.015650367364287376, ...
# 31  [-0.012720199301838875, -0.02136993408203125, ...
# 32  [0.00042087974725291133, -0.009129726327955723...
# 33  [-0.011847342364490032, -0.022175291553139687,...
# 34  [-0.0034045830834656954, -0.01926654949784279,...
# 35  [0.005881749093532562, -0.013807046227157116, ...
# 36  [-0.019068902358412743, -0.02421301044523716, ...
# 37  [-0.01371453981846571, -0.018868738785386086, ...
# 38  [-0.009416365064680576, -0.008958809077739716,...
# 39  [-0.0073934742249548435, -0.04465530440211296,...
# 40  [-0.01809169538319111, -0.02393232099711895, -...
# 41  [-0.003751352895051241, -0.033559400588274, -0...
# 42  [-0.01818343624472618, -0.035019952803850174, ...
# 43  [-0.013319134712219238, -0.04327452555298805, ...
# 44  [-0.020080624148249626, -0.020592818036675453,...
# 45  [-0.013710984960198402, -0.02610509656369686, ...
# 46  [-0.01564144343137741, -0.04094154015183449, 0...
# 47  [-0.011419424787163734, -0.02125830575823784, ...
# 48  [-0.007275617681443691, -0.03646231070160866, ...
# 49  [-0.021924767643213272, -0.019728370010852814,...
# 50  [-0.01168008428066969, -0.006861073896288872, ...
# 51  [0.0005217589205130935, -0.029348939657211304,...
# 52  [-0.0020250824745744467, -0.02221015840768814,...
# 53  [-0.013459227047860622, -0.010813452303409576,...
# 54  [-8.496997907059267e-05, -0.013627799227833748...

# %% [markdown]
# ## Custom Query Completion
#
# TODO: In the cells below, compose a custom query using your chosen dataset and retrieve results from an OpenAI `Completion` model. You may copy and paste any useful code from the course materials.

# %%
from openai.embeddings_utils import get_embedding, distances_from_embeddings

def get_rows_sorted_by_relevance(question, df):
    """
    Function that takes in a question string and a dataframe containing
    rows of text and associated embeddings, and returns that dataframe
    sorted from least to most relevant for that question
    """
    
    # Get embeddings for the question text
    question_embeddings = get_embedding(question, engine=EMBEDDING_MODEL_NAME)
    
    # Make a copy of the dataframe and add a "distances" column containing
    # the cosine distances between each row's embeddings and the
    # embeddings of the question
    df_copy = df.copy()
    df_copy["distances"] = distances_from_embeddings(
        question_embeddings,
        df_copy["embeddings"].values,
        distance_metric="cosine"
    )
    
    # Sort the copied dataframe by the distances and return it
    # (shorter distance = more relevant so we sort in ascending order)
    df_copy.sort_values("distances", ascending=True, inplace=True)
    return df_copy

# %%
get_rows_sorted_by_relevance("Who is Emily?", df)
# Out:
#                     Name                                        Description  \
# 0                  Emily  A young woman in her early 20s, Emily is an as...
# 2                  Alice  A woman in her late 30s, Alice is a warm and n...
# 5                 George  A man in his early 30s, George is a charming a...
# 6                 Rachel  A woman in her late 20s, Rachel is a shy and i...
# 26                Olivia  A confident and charismatic marketing executiv...
# 4                  Sarah  A woman in her mid-20s, Sarah is a free-spirit...
# 14                   Mia  A young Australian woman in her mid-20s, Mia i...
# 30                Sophia  A fun-loving and adventurous travel blogger, S...
# 49               Abigail  A plucky and resourceful young woman who works...
# 18                   Ava  A middle-aged Australian woman in her 50s, Ava...
# 33                  Jake  A laid-back and easygoing firefighter, Jake is...
# 40           Lady Olivia  A wealthy and beautiful noblewoman who has rec...
# 32                 Chloe  A driven and ambitious attorney, Chloe is alwa...
# 16                Tahlia  A young Indigenous Australian woman in her ear...
# 3                    Tom  A man in his 50s, Tom is a retired soldier and...
# 1                   Jack  A middle-aged man in his 40s, Jack is a succes...
# 11                 Sonya  A white woman in her late 20s, Sonya is a free...
# 28                  Maya  A kind and compassionate nurse with a heart of...
# 50                Thomas  A good-natured and affable young man who also ...
# 8                  Maria  A middle-aged Latina woman in her 40s, Maria i...
# 53           Mrs. Mercer  The matriarch of the wealthiest family in Will...
# 43                 Viola  A plucky and resourceful young woman who is sh...
# 22                 Dolly  A bubbly and vivacious performer, Dolly is a f...
# 24                 Karma  A chameleon-like performer, Karma is known for...
# 45                Bianca  Lady Olivia's cunning and quick-witted maid. B...
# 7                   John  A man in his 60s, John is a retired professor ...
# 42              Malvolio  A pompous and self-righteous steward in Lady O...
# 29                 James  A handsome and athletic personal trainer, Jame...
# 10                 Tyler  A white man in his mid-30s, Tyler is a tough-a...
# 25               Crystal  A quirky and imaginative performer, Crystal is...
# 17                   Max  A white Australian man in his late 20s, Max is...
# 20                Johnny  A young up-and-coming performer, Johnny is ful...
# 23                 Vixen  A fierce and competitive performer, Vixen is a...
# 52         Captain James  The charismatic and dashing captain of the loc...
# 51        Reverend Brown  The pious and stern minister of the local chur...
# 35          Signora Rosa  A mysterious and alluring woman who runs a loc...
# 37             Francesca  A fiery and passionate young woman who works a...
# 39           Duke Orsino  A pompous and self-important nobleman who is h...
# 32  Chloe is a character in a Reality Show. A driv...
# 16  Tahlia is a character in a Limited Series. A y...
# 3   Tom is a character in a Play. A man in his 50s...
# 1   Jack is a character in a Play. A middle-aged m...
# 11  Sonya is a character in a Movie. A white woman...
# 28  Maya is a character in a Reality Show. A kind ...
# 50  Thomas is a character in a Sitcom. A good-natu...
# 8   Maria is a character in a Movie. A middle-aged...
# 53  Mrs. Mercer is a character in a Sitcom. The ma...
# 43  Viola is a character in a Play. A plucky and r...
# 22  Dolly is a character in a Musical. A bubbly an...
# 24  Karma is a character in a Musical. A chameleon...
# 45  Bianca is a character in a Play. Lady Olivia's...
# 7   John is a character in a Play. A man in his 60...
# 42  Malvolio is a character in a Play. A pompous a...
# 29  James is a character in a Reality Show. A hand...
# 10  Tyler is a character in a Movie. A white man i...
# 25  Crystal is a character in a Musical. A quirky ...
# 17  Max is a character in a Limited Series. A whit...
# 20  Johnny is a character in a Musical. A young up...
# 23  Vixen is a character in a Musical. A fierce an...
# 52  Captain James is a character in a Sitcom. The ...
# 51  Reverend Brown is a character in a Sitcom. The...
# 35  Signora Rosa is a character in a Opera. A myst...
# 37  Francesca is a character in a Opera. A fiery a...
# 39  Duke Orsino is a character in a Play. A pompou...
# 15  Lucas is a character in a Limited Series. A mi...
# 31  Noah is a character in a Reality Show. A quirk...
# 47  Feste is a character in a Play. A jester and m...
# 21  Sable is a character in a Musical. A sultry an...
# 9   Caleb is a character in a Movie. A young Afric...
# 13  Will is a character in a Movie. A white man in...
# 46  Sebastian is a character in a Play. Viola's tw...
# 19  Donna is a character in a Musical. A seasoned ...
# 27  Marcus is a character in a Reality Show. A cha...
# 44  Sir Andrew Aguecheek is a character in a Play....
# 41  Sir Toby Belch is a character in a Play. A dru...
# 54  Mr. Mercer is a character in a Sitcom. The bum...
# 12  Manuel is a character in a Movie. A middle-age...
# 48  Antonio is a character in a Play. A sea captai...
# 34  Prince Lorenzo is a character in a Opera. A ch...
# 36  Baron Gustavo is a character in a Opera. A wea...
# 38  Don Carlo is a character in a Opera. A charmin...
#
#                                            embeddings  distances
# 0   [-0.016368035227060318, -0.014631644822657108,...   0.114040
# 2   [0.007741514127701521, -0.011314022354781628, ...   0.170748
# 5   [-0.01863767020404339, -0.015743380412459373, ...   0.193296
# 6   [-0.006452818401157856, -0.014104107394814491,...   0.214381
# 26  [-0.00042307059629820287, -0.01519947499036789...   0.218513
# 4   [-0.01451121736317873, -0.03126079961657524, -...   0.220237
# 14  [-0.012351165525615215, -0.022184068337082863,...   0.223251
# 30  [0.024226823821663857, -0.015650367364287376, ...   0.224164
# 49  [-0.021924767643213272, -0.019728370010852814,...   0.224644
# 18  [9.845461318036541e-05, -0.013735860586166382,...   0.228283
# 33  [-0.011847342364490032, -0.022175291553139687,...   0.230530
# 40  [-0.01809169538319111, -0.02393232099711895, -...   0.232110
# 32  [0.00042087974725291133, -0.009129726327955723...   0.233663
# 16  [-0.011918366886675358, -0.014478801749646664,...   0.234723
# 3   [0.015514831058681011, -0.020425723865628242, ...   0.236999
# 1   [0.0023951339535415173, -0.027941077947616577,...   0.240397
# 11  [0.0028479069005697966, -0.027940496802330017,...   0.242443
# 28  [-0.02221345342695713, -0.0217245202511549, -0...   0.242664
# 50  [-0.01168008428066969, -0.006861073896288872, ...   0.243157
# 8   [-0.01244370173662901, -0.019594186916947365, ...   0.243582
# 53  [-0.013459227047860622, -0.010813452303409576,...   0.244106
# 43  [-0.013319134712219238, -0.04327452555298805, ...   0.248439
# 22  [-0.035160064697265625, -0.01963837258517742, ...   0.249591
# 24  [-0.00107478816062212, -0.02119309827685356, 0...   0.250758
# 45  [-0.013710984960198402, -0.02610509656369686, ...   0.252727
# 7   [0.017432034015655518, -0.017279010266065598, ...   0.254350
# 42  [-0.01818343624472618, -0.035019952803850174, ...   0.255685
# 29  [-0.017906880006194115, -0.010714348405599594,...   0.258405
# 10  [0.009816470555961132, -0.049798741936683655, ...   0.258762
# 25  [-0.006420883350074291, -0.02087603509426117, ...   0.259971
# 17  [-0.00026815407909452915, -0.03790075331926346...   0.260147
# 20  [-0.028036687523126602, -0.021027516573667526,...   0.260839
# 23  [-0.03357435762882233, -0.026927525177598, 0.0...   0.263297
# 52  [-0.0020250824745744467, -0.02221015840768814,...   0.263565
# 51  [0.0005217589205130935, -0.029348939657211304,...   0.264132
# 35  [0.005881749093532562, -0.013807046227157116, ...   0.264889
# 37  [-0.01371453981846571, -0.018868738785386086, ...   0.265481
# 39  [-0.0073934742249548435, -0.04465530440211296,...   0.266127
# 15  [0.0026741118635982275, -0.0170036181807518, -...   0.266282
# 31  [-0.012720199301838875, -0.02136993408203125, ...   0.268032
# 47  [-0.011419424787163734, -0.02125830575823784, ...   0.268216
# 21  [-0.029506079852581024, -0.01870235614478588, ...   0.268309
# 9   [0.006574748549610376, -0.030858173966407776, ...   0.271009
# 13  [-0.00728572066873312, -0.04460698738694191, -...   0.271409
# 46  [-0.01564144343137741, -0.04094154015183449, 0...   0.273832
# 19  [-0.02831415645778179, -0.01762465015053749, 0...   0.275091
# 27  [0.0003506191133055836, -0.03934405371546745, ...   0.280763
# 44  [-0.020080624148249626, -0.020592818036675453,...   0.281191
# 41  [-0.003751352895051241, -0.033559400588274, -0...   0.282309
# 54  [-8.496997907059267e-05, -0.013627799227833748...   0.285462
# 12  [-0.014727214351296425, -0.023791132494807243,...   0.289857
# 48  [-0.007275617681443691, -0.03646231070160866, ...   0.292156
# 34  [-0.0034045830834656954, -0.01926654949784279,...   0.297873
# 36  [-0.019068902358412743, -0.02421301044523716, ...   0.305821
# 38  [-0.009416365064680576, -0.008958809077739716,...   0.308000

# %%
import tiktoken

def create_prompt(question, df, max_token_count):
    """
    Given a question and a dataframe containing rows of text and their
    embeddings, return a text prompt to send to a Completion model
    """
    # Create a tokenizer that is designed to align with our embeddings
    tokenizer = tiktoken.get_encoding("cl100k_base")
    
    # Count the number of tokens in the prompt template and question
    prompt_template = """
Answer the question based on the context below, and if the question
can't be answered based on the context, say "I don't know"

Context: 

{}

---

Question: {}
Answer:"""
    
    current_token_count = len(tokenizer.encode(prompt_template)) + \
                            len(tokenizer.encode(question))
    
    context = []
    for text in get_rows_sorted_by_relevance(question, df)["text"].values:
        
        # Increase the counter based on the number of tokens in this row
        text_token_count = len(tokenizer.encode(text))
        current_token_count += text_token_count
        
        # Add the row of text to the list if we haven't exceeded the max
        if current_token_count <= max_token_count:
            context.append(text)
        else:
            break

    return prompt_template.format("\n\n###\n\n".join(context), question)

# %%
print(create_prompt("Who is Emily?", df, 200))
# Out:
# Answer the question based on the context below, and if the question
# can't be answered based on the context, say "I don't know"
#
# Context:
#
# Emily is a character in a Play. A young woman in her early 20s, Emily is an aspiring actress and Alice's daughter. She has a bubbly personality and a quick wit, but struggles with self-doubt and insecurity. She's also in a relationship with George. The story is set in England.
#
# ###
#
# Alice is a character in a Play. A woman in her late 30s, Alice is a warm and nurturing mother of two, including Emily. She's kind-hearted and empathetic, but can be overly protective of her children and prone to worrying. She's married to Jack. The story is set in England.
#
# ---
#
# Question: Who is Emily?
# Answer:

# %%
COMPLETION_MODEL_NAME = "gpt-3.5-turbo-instruct"

def openai_query(prompt, max_answer_tokens=150):
    """
    Given a prompt, query the openapi.Completion model.
    Return the first response choice from the model.
    """
    try:
        response = openai.Completion.create(
            model=COMPLETION_MODEL_NAME,
            prompt=prompt,
            max_tokens=max_answer_tokens
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""

def answer_question(question, df, max_prompt_tokens=1800, max_answer_tokens=150):
    """
    Given a question, a dataframe containing rows of text, and a maximum
    number of desired tokens in the prompt and response, return the
    answer to the question according to an OpenAI Completion model
    
    If the model produces an error, return an empty string
    """
    
    prompt = create_prompt(question, df, max_prompt_tokens)
    
    return openai_query(prompt, max_answer_tokens)

# %% [markdown]
# ## Custom Performance Demonstration
#
# TODO: In the cells below, demonstrate the performance of your custom query using at least 2 questions. For each question, show the answer from a basic `Completion` model query as well as the answer from your custom query.

# %% [markdown]
# ### Question 1

# %%
question = "Who is Emily?"
emily_answer = openai_query(question)
print(emily_answer)
# Out:
# There is not enough information to determine who Emily is. It is a fairly common name and could refer to anyone.

# %%
emily_answer = answer_question(question, df)
print(emily_answer)
# Out:
# Emily is a character in a play, an aspiring actress and Alice's daughter. She is in a relationship with George and struggles with self-doubt and insecurity. The story is set in England.

# %% [markdown]
# ### Question 2

# %%
question = "Who is Alice daughter?"
emily_answer = openai_query(question)
print(emily_answer)
# Out:
# It depends on which Alice you are referring to. There are many fictional characters named Alice, and their daughters may have different names or may not even exist in the story. If you are referring to the traditional character of Alice in "Alice's Adventures in Wonderland" by Lewis Carroll, she does not have a daughter. However, in some adaptations and sequels to the story, she may have a daughter named Lily or Dinah.

# %%
emily_answer = answer_question(question, df)
print(emily_answer)
# Out:
# Emily.
